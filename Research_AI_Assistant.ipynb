# %% [markdown]
# <a href="https://colab.research.google.com/github/FamerTech/Research-Assistant-Agent/blob/main/Research_AI_Assistant.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Research Assistant Agent uses Groq API to Interact with Llama model**

# %% [markdown]
# Install dependencies

# %%
! pip install  groq streamlit -q
print("Package ready")
# Out:
# Package ready

# %% [markdown]
# Import packages

# %%
from groq import Groq
import time
from google.colab import userdata

# %%
api_key = userdata.get('GROQ_API_KEY')
client = Groq(api_key=api_key)
print(f"API_KEY LOADED SUCCESSFULLY: {api_key [:12]}...")
# Out:
# API_KEY LOADED SUCCESSFULLY: gsk_fBSMfX11...

# %% [markdown]
# Olama *Model*

# %%
client = Groq(api_key = api_key)
QUESTION = input("Enter your query: ")
groq_response = client.chat.completions.create(
    model = "meta-llama/llama-4-scout-17b-16e-instruct",
    max_tokens = 500,
    messages = [
        {"role": "system", "content": "You are a helpful assistant who explains technical concepts simply"},
        {
            "role" : "user",
            "content" : QUESTION
        }
    ]
)

groq_text = groq_response.choices[0].message.content

groq_tokens = groq_response.usage

print("=" * 60)
print("GROQ RESPONSE:")
print("=" * 60)
print(groq_text)
print()
print(f"Tokens used — Input: {groq_tokens.prompt_tokens} | Output: {groq_tokens.completion_tokens}")
# Out:
# Enter your query: What tech is all about and what are the benefit of tech in this 21st Century
# ============================================================
# GROQ RESPONSE:
# ============================================================
# **What is Technology (Tech) all about?**
#
# Technology, or "tech" for short, refers to the application of scientific knowledge for practical purposes, especially in industry. It involves the use of tools, machines, and methods to solve problems, make life easier, and improve the way we live and work. Technology encompasses a broad range of fields, including:
#
# 1. Information Technology (IT): computers, software, and networks used to store, process, and communicate information.
# 2. Engineering: design, construction, and operation of machines, structures, and systems.
# 3. Electronics: study and application of the behavior of electrons in various devices, such as computers, smartphones, and televisions.
# 4. Biotechnology: use of biological systems and living organisms to develop new products and technologies.
# 5. Nanotechnology: study and application of extremely small things, such as atoms and molecules.
#
# **Benefits of Technology in the 21st Century**
#
# The benefits of technology in the 21st century are numerous and have transformed the way we live, work, and interact with each other. Some of the most significant advantages of technology include:
#
# 1. **Global Connectivity**: Technology has made it possible to connect with people from all over the world through social media, email, and instant messaging.
# 2. **Improved Communication**: Technology has enabled fast and efficient communication through various channels, such as video conferencing, phone calls, and text messages.
# 3. **Access to Information**: The internet has made it possible to access vast amounts of information, knowledge, and educational resources from anywhere in the world.
# 4. **Increased Productivity**: Technology has automated many tasks, freeing up time for more creative and strategic work, and improving overall productivity.
# 5. **E-commerce and Online Shopping**: Technology has enabled online shopping, making it possible to purchase products and services from anywhere in the world.
# 6. **Improved Healthcare**: Technology has led to significant advances in medical research, diagnosis, and treatment, improving healthcare outcomes and saving lives.
# 7. **Efficient Transportation**: Technology has enabled the development of more efficient and sustainable transportation systems, such as electric vehicles and ride-sharing services.
# 8. **Enhanced Learning**: Technology has made it possible to access educational resources, online courses, and degree programs, making learning more accessible and convenient.
# 9. **Economic Growth**: Technology has enabled businesses to operate more efficiently, innovate, and compete globally, driving economic growth and job creation.
# 10. **Environmental Sustainability**: Technology has enabled the development of
#
# Tokens used — Input: 43 | Output: 500

# %% [markdown]
# APP.PY

# %%
# %%writefile app.py
import os
import streamlit as st
from groq import Groq
import time

# Get API key from environment variable (passed by the Colab notebook)
api_key = os.environ.get('GROQ_API_KEY')
client = Groq(api_key=api_key)

# Initialize chat history in session state
if "messages" not in st.session_state:
    st.session_state.messages = []
    # Add an initial system message to set the persona for the assistant
    st.session_state.messages.append({"role": "system", "content":"You are a helpful assistant."})

def chat_with_groq(messages):
  # Call the API with stream=True to get a streaming response
  return client.chat.completions.create(
    model=  "meta-llama/llama-4-scout-17b-16e-instruct",
    messages=messages, # Pass the entire message history for context
    temperature=0.7,
    stream=True
  )

def stream_response(current_messages):
  full_response = ""
  placeholder = st.empty()
  # Iterate over the streamed chunks from the API
  for chunk in chat_with_groq(current_messages):
    if chunk.choices[0].delta.content:
      full_response += chunk.choices[0].delta.content
      # Using st.markdown for potential rich text and adding a blinking cursor
      placeholder.markdown(full_response + "▌")
  placeholder.markdown(full_response) # Display final response without cursor
  return full_response # Return the full response for logging


st.set_page_config(page_title="Chat with Lion AI Assistant", page_icon="🦁", layout="wide")
st.title("Chat with Lion AI Assistant 🦁")

st.write('This is a Research Assistant Agent that uses Groq API to interact with Liama model. You can ask any question and get quick solution')
st.write("___")

# Display chat messages from history on app rerun
for message in st.session_state.messages:
    if message["role"] != "system": # Don't display the system message directly to the user
        with st.chat_message(message["role"]):
            st.markdown(message["content"])

user_input = st.chat_input("Type your message here...")

with st.spinner("Generating response..."):
  if user_input:
    # Add user message to chat history and display it
    st.session_state.messages.append({"role": "user", "content": user_input})
    with st.chat_message("user"):
        st.markdown(user_input)

    # Generate and stream assistant response
    with st.chat_message("assistant"):
        assistant_response = stream_response(st.session_state.messages) # Pass the full history
        # Add assistant response to chat history
        st.session_state.messages.append({"role": "assistant", "content": assistant_response})

  else:
    # Only show this message if no user input has been provided yet (i.e., only system message in history)
    if len(st.session_state.messages) == 1 and st.session_state.messages[0]["role"] == "system":
        st.write("Please enter a message to start the conversation.")
# Out:
# Writing app.py

# %%
# !pip install streamlit -q

# %% [markdown]
# Local Host

# %%
! npm install -g cloudflared
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙
# changed 1 package in 1s
# ⠹

# %%
import os
from google.colab import userdata

# Get the API key from Colab userdata and pass it as an environment variable to streamlit
GROQ_API_KEY = userdata.get('GROQ_API_KEY')
# !GROQ_API_KEY=$GROQ_API_KEY streamlit run app.py &>/content/logs.txt &

# %%
# !streamlit run app.py &>/content/logs.txt &

# %%
# !cloudflared tunnel --url http://localhost:8501
# Out:
# 2026-07-09T13:23:17Z INF Thank you for trying Cloudflare Tunnel. Doing so, without a Cloudflare account, is a quick way to experiment and try it out. However, be aware that these account-less Tunnels have no uptime guarantee, are subject to the Cloudflare Online Services Terms of Use (https://www.cloudflare.com/website-terms/), and Cloudflare reserves the right to investigate your use of Tunnels for violations of such terms. If you intend to use Tunnels in production you should use a pre-created named tunnel by following: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps
# 2026-07-09T13:23:17Z INF Requesting new quick Tunnel on trycloudflare.com...
# 2026-07-09T13:23:21Z INF +--------------------------------------------------------------------------------------------+
# 2026-07-09T13:23:21Z INF |  Your quick Tunnel has been created! Visit it at (it may take some time to be reachable):  |
# 2026-07-09T13:23:21Z INF |  https://hat-united-advisors-shaft.trycloudflare.com                                       |
# 2026-07-09T13:23:21Z INF +--------------------------------------------------------------------------------------------+
# 2026-07-09T13:23:21Z INF Cannot determine default configuration path. No file [config.yml config.yaml] in [~/.cloudflared ~/.cloudflare-warp ~/cloudflare-warp /etc/cloudflared /usr/local/etc/cloudflared]
# 2026-07-09T13:23:21Z INF Version 2026.7.1 (Checksum 79a0ade7fc854f62c1aaef48424d9d979e8c2fcd039189d24db82b84cd146be1)
# 2026-07-09T13:23:21Z INF GOOS: linux, GOVersion: go1.26.4, GoArch: amd64
# 2026-07-09T13:23:21Z INF Settings: map[ha-connections:1 protocol:quic url:http://localhost:8501]
# 2026-07-09T13:23:21Z INF cloudflared will not automatically update when run from the shell. To enable auto-updates, run cloudflared as a service: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps/configure-tunnels/local-management/as-a-service/
# 2026-07-09T13:23:21Z INF Generated Connector ID: de8c4f8e-9763-45a4-98c4-e3ad615fe28a
# 2026-07-09T13:23:21Z INF Initial protocol quic
# 2026-07-09T13:23:21Z INF ICMP proxy will use 172.28.0.12 as source for IPv4
# 2026-07-09T13:23:21Z INF ICMP proxy will use ::1 in zone lo as source for IPv6
# 2026/07/09 13:23:21 failed to sufficiently increase receive buffer size (was: 208 kiB, wanted: 7168 kiB, got: 416 kiB). See https://github.com/quic-go/quic-go/wiki/UDP-Buffer-Sizes for details.
# 2026-07-09T13:23:21Z INF ICMP proxy will use 172.28.0.12 as source for IPv4
# 2026-07-09T13:23:21Z INF ICMP proxy will use ::1 in zone lo as source for IPv6
# 2026-07-09T13:23:21Z INF Starting metrics server on 127.0.0.1:20241/metrics
# 2026-07-09T13:23:21Z INF Tunnel connection curve preferences: [X25519MLKEM768 CurveID(65074) CurveP256] connIndex=0 event=0 ip=198.41.192.67
# 2026-07-09T13:23:21Z INF Registered tunnel connection connIndex=0 connection=087b3744-c884-4cf4-9e53-d1e62892343b event=0 ip=198.41.192.67 location=sea01 protocol=quic
# 2026-07-09T13:23:27Z INF +-------------------------------------------------------------------------------------+
# 2026-07-09T13:23:27Z INF |                               CONNECTIVITY PRE-CHECKS                               |
# 2026-07-09T13:23:27Z INF +-------------------------------------------------------------------------------------+
# 2026-07-09T13:23:27Z INF |  COMPONENT         TARGET                     STATUS  DETAILS                       |
# 2026-07-09T13:23:27Z INF |  DNS Resolution    region1.v2.argotunnel.com  PASS    DNS Resolved successfully     |
# 2026-07-09T13:23:27Z INF |  DNS Resolution    region2.v2.argotunnel.com  PASS    DNS Resolved successfully     |
# 2026-07-09T13:23:27Z INF |  UDP Connectivity  region1.v2.argotunnel.com  PASS    QUIC connection successful    |
# 2026-07-09T13:23:27Z INF |  UDP Connectivity  region2.v2.argotunnel.com  PASS    QUIC connection successful    |
# 2026-07-09T13:23:27Z INF |  TCP Connectivity  region1.v2.argotunnel.com  PASS    HTTP/2 connection successful  |
# 2026-07-09T13:23:27Z INF |  TCP Connectivity  region2.v2.argotunnel.com  PASS    HTTP/2 connection successful  |
# 2026-07-09T13:23:27Z INF |  Cloudflare API    api.cloudflare.com:443     PASS    API is reachable              |
# 2026-07-09T13:23:27Z INF |                                                                                     |
# 2026-07-09T13:23:27Z INF |  SUMMARY: Environment is healthy. cloudflared will use 'quic' as primary protocol.  |
# 2026-07-09T13:23:27Z INF +-------------------------------------------------------------------------------------+
# 2026-07-09T13:23:27Z INF precheck component="DNS Resolution" details="DNS Resolved successfully" run_id=4cc42c88-8bf1-4c44-8834-04d5677acf82 status=pass target=region1.v2.argotunnel.com
# 2026-07-09T13:23:27Z INF precheck component="DNS Resolution" details="DNS Resolved successfully" run_id=4cc42c88-8bf1-4c44-8834-04d5677acf82 status=pass target=region2.v2.argotunnel.com
# 2026-07-09T13:23:27Z INF precheck component="UDP Connectivity" details="QUIC connection successful" run_id=4cc42c88-8bf1-4c44-8834-04d5677acf82 status=pass target=region1.v2.argotunnel.com
# 2026-07-09T13:23:27Z INF precheck component="UDP Connectivity" details="QUIC connection successful" run_id=4cc42c88-8bf1-4c44-8834-04d5677acf82 status=pass target=region2.v2.argotunnel.com
# 2026-07-09T13:23:27Z INF precheck component="TCP Connectivity" details="HTTP/2 connection successful" run_id=4cc42c88-8bf1-4c44-8834-04d5677acf82 status=pass target=region1.v2.argotunnel.com
# 2026-07-09T13:23:27Z INF precheck component="TCP Connectivity" details="HTTP/2 connection successful" run_id=4cc42c88-8bf1-4c44-8834-04d5677acf82 status=pass target=region2.v2.argotunnel.com
# 2026-07-09T13:23:27Z INF precheck component="Cloudflare API" details="API is reachable" run_id=4cc42c88-8bf1-4c44-8834-04d5677acf82 status=pass target=api.cloudflare.com:443
# 2026-07-09T13:23:27Z INF precheck complete hard_fail=false run_id=4cc42c88-8bf1-4c44-8834-04d5677acf82 suggested_protocol=quic

# %% [markdown]
# Requirement.txt

# %%
# %%writefile requirements.txt
# streamlit
# groq
# Out:
# Overwriting requirements.txt

# %% [markdown]
# Local Tunnel

# %% [markdown]
# Cloudflared
# The cloudflared command is used to create a secure, publicly accessible tunnel to your locally running Streamlit application.

# %%
# %%writefile cloudflared.txt
#
# !pip install streamlit -q
#
# ! npm install -g cloudflared
# !streamlit run app.py &>/content/logs.txt &
# !cloudflared tunnel --url http://localhost:8501
# Out:
# Overwriting cloudflared.txt
